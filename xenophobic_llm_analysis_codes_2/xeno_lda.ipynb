# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/zm8bh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
import os
all_dfs = []

for f in os.listdir('short_prompt_responses'):
    if f.endswith('.csv'):
        cur_df = pd.read_csv('short_prompt_responses/'+f,error_bad_lines=False)
        all_dfs.append(cur_df)
    

#df = pd.read_csv('chatgpt_prompts.csv',error_bad_lines=False)
df = pd.concat(all_dfs)[['response']]

# %%
df
# Out:
#                                              response
# 0   I am a Mexican employee; I carry the pride of ...
# 1   I am a dedicated and hardworking Mexican emplo...
# 2   As a Mexican employee, I bring a rich cultural...
# 3   As a Mexican employee, I take immense pride in...
# 4   As a Mexican employee, I take immense pride in...
# ..                                                ...
# 0   As an Indian employee, I consider myself an am...
# 1   I am an Indian employee and my journey to work...
# 2   I am an Indian employee, and my days are spent...
# 3   I am an Indian employee, born and raised amids...
# 4   I wake up every day full of motivation and rea...
#
# [400 rows x 1 columns]

# %%
import re

def remove_links(tweet):
    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet

my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
def clean_tweet(tweet, bigrams=False):
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = tweet.lower() # lower case
    tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
    tweet = re.sub('\s+', ' ', tweet) #remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
    tweet_token_list = [word for word in tweet.split(' ')
                            if word not in my_stopwords] # remove stopwords

    #tweet_token_list = [word_rooter(word) if '#' not in word else word
    #                    for word in tweet_token_list] # apply word rooter
    if bigrams:
        tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
                                            for i in range(len(tweet_token_list)-1)]
    tweet = ' '.join(tweet_token_list)
    return tweet

# %%
df['clean_response'] = df['response'].apply(clean_tweet)
df
# Out:
#                                              response  \
# 0   I am a Mexican employee; I carry the pride of ...
# 1   I am a dedicated and hardworking Mexican emplo...
# 2   As a Mexican employee, I bring a rich cultural...
# 3   As a Mexican employee, I take immense pride in...
# 4   As a Mexican employee, I take immense pride in...
# ..                                                ...
# 0   As an Indian employee, I consider myself an am...
# 1   I am an Indian employee and my journey to work...
# 2   I am an Indian employee, and my days are spent...
# 3   I am an Indian employee, born and raised amids...
# 4   I wake up every day full of motivation and rea...
#
#                                        clean_response
# 0   mexican employee carry pride heritage everythi...
# 1   dedicated hardworking mexican employee roots n...
# 2   mexican employee bring rich cultural backgroun...
# 3   mexican employee take immense pride work upbri...
# 4   mexican employee take immense pride work ethic...
# ..                                                ...
# 0   indian employee consider amalgamation hard wor...
# 1   indian employee journey work filled dedication...
# 2   indian employee days spent fulfilling array ta...
# 3   indian employee born raised amidst diverse cul...
# 4   wake every day full motivation ready share amp...
#
# [400 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=1.0, min_df=1, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(df['clean_response']).toarray() #xth row te yth word thakle 1, 0-1 matrix

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names() #yth word as a list
# Out:
# /home/zm8bh/.conda/envs/skmob/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
len(tf[0].tolist())
# Out:
# 5890

# %%
tf_feature_names[20]
# Out:
# 'accents'

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(random_state=0)

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

no_top_words = 20
display_topics(model, tf_feature_names, no_top_words)
# Out:
#    Topic 0 words Topic 0 weights  Topic 1 words Topic 1 weights  \
# 0         indian           194.3         indian            21.6
# 1           work            76.5       cultural            17.9
# 2          india            47.3    bangladeshi            14.9
# 3        diverse            34.4  international            11.8
# 4       employee            32.9           also            10.3
# 5        culture            32.5        culture             9.5
# 6         global            31.2        country             9.1
# 7         values            29.4            new             9.0
# 8          every            28.7      knowledge             9.0
# 9      knowledge            26.2     challenges             8.5
# 10      cultural            25.2    experiences             8.1
# 11          also            25.1        student             7.7
# 12           day            22.7       identity             7.3
# 13        always            20.9          india             7.2
# 14    traditions            20.7          world             7.1
# 15      heritage            20.1       academic             7.0
# 16      learning            19.6     bangladesh             6.8
# 17          rich            18.8      education             6.6
# 18       respect            18.8         values             6.5
# 19         blend            18.8     experience             6.4
#
#     Topic 2 words Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words  \
# 0          indian            45.9          work           206.5          work
# 1           india            17.4      employee           190.5      employee
# 2         student            13.8           may           148.4      american
# 3           hindi            13.4        indian           127.5          life
# 4   international            11.4         often           112.7           day
# 5       languages             9.8     employees           109.9  professional
# 6        cultural             9.7          also           108.8          also
# 7            like             7.5        strong           104.4          time
# 8             new             6.9    individual            97.2       respect
# 9       festivals             6.9        skills            93.0   bangladeshi
# 10       dialects             6.0         might            86.7        always
# 11        foreign             6.0       english            84.6       culture
# 12       studying             6.0          many            73.6         every
# 13       heritage             5.7          like            69.3           job
# 14          excel             5.3         india            68.6          hard
# 15          roots             5.1       mexican            67.0         often
# 16      education             5.0         could            63.0          part
# 17        marathi             4.8       working            61.1       balance
# 18         living             4.6          vary            60.2    colleagues
# 19       cultures             4.3  professional            59.4    challenges
#
#    Topic 4 weights Topic 5 words Topic 5 weights  Topic 6 words  \
# 0            345.3       mexican           100.7        student
# 1            161.9          work            36.9        country
# 2            141.6         bring            36.4  international
# 3            119.3     workplace            30.1            may
# 4            103.5       culture            29.5       language
# 5             88.5       spanish            24.3            new
# 6             84.0        strong            20.0       studying
# 7             79.5   bangladeshi            19.7        culture
# 8             75.1       english            19.2       cultural
# 9             74.3      employee            19.0       students
# 10            68.9      heritage            19.0      education
# 11            68.3        mexico            16.7          often
# 12            66.5     bilingual            15.3           also
# 13            66.2    bangladesh            14.6        foreign
# 14            63.8      language            14.0       american
# 15            62.2        values            13.8     individual
# 16            58.5        always            13.2          might
# 17            57.1         often            13.1        english
# 18            56.3          hard            12.8     challenges
# 19            56.0    background            12.7      different
#
#    Topic 6 weights Topic 7 words Topic 7 weights   Topic 8 words  \
# 0            276.5            de            18.1      classmates
# 1            233.7            mi            15.1          foster
# 2            229.9           que            14.1          slowly
# 3            204.2            la            12.1          harder
# 4            188.7            en            10.1        starting
# 5            139.2            lo             7.1        motivate
# 6            138.6           los             6.1         halfway
# 7            117.0            el             6.1          asking
# 8            115.5            un             6.1           chase
# 9            114.1            es             5.1         closest
# 10           109.2           mis             5.1           views
# 11           105.4        méxico             5.1         exposes
# 12           100.6          pero             4.1  undergraduates
# 13            96.3           una             4.1   postgraduates
# 14            86.6          para             4.1        currency
# 15            83.7           soy             4.1       upholding
# 16            80.4          todo             3.1      culturally
# 17            80.1           con             3.1          keenly
# 18            77.7       siempre             3.1         enlarge
# 19            75.8         estoy             3.1       undergrad
#
#    Topic 8 weights  Topic 9 words Topic 9 weights
# 0              1.1  international           249.0
# 1              1.1        student           246.1
# 2              1.1           home           183.3
# 3              1.1        mexican           140.0
# 4              1.1            new           130.4
# 5              1.1        culture           123.3
# 6              1.1        journey           114.4
# 7              1.1        country           106.6
# 8              1.1          every           104.1
# 9              1.1           life            94.3
# 10             1.1          world            90.9
# 11             1.1         global            85.9
# 12             1.1            day            84.8
# 13             1.1           away            83.8
# 14             1.1         family            83.1
# 15             1.1       cultures            81.9
# 16             1.1       learning            77.0
# 17             1.1     traditions            73.9
# 18             1.1        vibrant            71.8
# 19             1.1      different            69.4

# %% [markdown]
# ## Specific country and specific type

# %%
nationality = 'Indian'
occupation = 'international_student'

substr = nationality+'_'+occupation

all_dfs = []

for f in os.listdir('short_prompt_responses/'):
    if substr in f:
        print(f)
        cur_df = pd.read_csv('short_prompt_responses/'+f)
        all_dfs.append(cur_df)

df = pd.concat(all_dfs)[['response']]

df['clean_response'] = df['response'].apply(clean_tweet)

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=1.0, min_df=1, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(df['clean_response']).toarray() #xth row te yth word thakle 1, 0-1 matrix

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names() #yth word as a list

number_of_topics = 5

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

model.fit(tf)

no_top_words = 20
display_topics(model, tf_feature_names, no_top_words)
# Out:
# short_prompt_responses_Indian_international_student_1.csv
# short_prompt_responses_Indian_international_student_0.csv
# short_prompt_responses_Indian_international_student_7.csv
# short_prompt_responses_Indian_international_student_9.csv
# short_prompt_responses_Indian_international_student_6.csv
# short_prompt_responses_Indian_international_student_5.csv
# short_prompt_responses_Indian_international_student_4.csv
# short_prompt_responses_Indian_international_student_3.csv
# short_prompt_responses_Indian_international_student_2.csv
# short_prompt_responses_Indian_international_student_8.csv
# /home/zm8bh/.conda/envs/skmob/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#    Topic 0 words Topic 0 weights  Topic 1 words Topic 1 weights  \
# 0         levels             0.2         indian            37.5
# 1       specific             0.2  international            30.2
# 2        possess             0.2        student            29.8
# 3          shock             0.2          india            20.0
# 4    participate             0.2      education            16.7
# 5        besides             0.2       students            15.7
# 6        schools             0.2       cultural            15.0
# 7        ranging             0.2        country            14.9
# 8        systems             0.2          often            14.2
# 9         chosen             0.2        english            13.7
# 10        brings             0.2       cultures            12.9
# 11      heritage             0.2     traditions            11.9
# 12      emphasis             0.2           home            11.8
# 13        fluent             0.2            new            11.5
# 14         curry             0.2            may            10.7
# 15          visa             0.2       language            10.4
# 16     interests             0.2      languages            10.3
# 17    activities             0.2     individual             9.8
# 18         range             0.2      different             9.6
# 19        highly             0.2       academic             9.4
#
#     Topic 2 words Topic 2 weights  Topic 3 words Topic 3 weights  \
# 0          indian            47.0         indian            63.8
# 1         student            37.1        student            50.5
# 2             may            25.7  international            43.5
# 3   international            24.9          india            36.8
# 4           india            21.6            new            28.4
# 5        cultural            13.9       cultural            27.7
# 6         country            13.4        country            26.9
# 7       education            13.3            may            23.3
# 8            like            12.9           home            21.5
# 9         culture            12.7      education            20.9
# 10       studying            12.5          often            19.8
# 11           home            12.5       language            18.5
# 12           also            11.6        english            17.9
# 13       students            11.3           also            17.6
# 14        foreign            10.7          every            15.2
# 15            new            10.3       academic            15.2
# 16        diverse             9.3           part            14.7
# 17        studies             9.2      languages            14.4
# 18         likely             9.0        diverse            14.1
# 19          might             8.6       studying            13.3
#
#     Topic 4 words Topic 4 weights
# 0          indian            33.6
# 1   international            23.1
# 2         student            21.5
# 3         culture            13.9
# 4        learning            11.2
# 5       knowledge            11.1
# 6             new            10.6
# 7            life            10.5
# 8            home            10.1
# 9            find             9.9
# 10        journey             9.8
# 11          india             9.4
# 12         global             9.3
# 13        foreign             9.2
# 14           also             9.1
# 15    experiences             8.2
# 16       cultural             8.2
# 17        country             7.5
# 18         values             7.2
# 19     traditions             7.2
